# %%
import pandas as pd, numpy as np, os

current_directory = os.getcwd()
PKL = os.path.join(current_directory, 'PKL')
Figures = os.path.join(current_directory, 'figures')
Files = os.path.join(current_directory, 'text_files')
CSV = os.path.join(current_directory, 'csv_files')

from utils.x_plots import plot_global, plot_decadal_compact, plot_single_journey, plot_time_range

# %%
#select your tier - all figures for the manuscript use tier 4
tier = 4
fname = f"Tier{tier}.pkl"

print(f"Loading Tier {tier} data...")
try:
    df = pd.read_pickle(os.path.join(PKL, fname))
    print("File loaded!")
except FileNotFoundError:
    print(f"Error: {fname} not found.")
# Out:
# Loading Tier 4 data...
# File loaded!

# %%
temp_df = df.copy()
df_coords = temp_df[temp_df["Latitude_decimal"].notna() & temp_df["Longitude_decimal"].notna()]
df_usable = df_coords[df_coords['Tier4_usable'] == True]

# %%
# #saving after last corrections
# df.to_csv(f'{CSV}/post_xtra_inspec_logbooks.csv', index=False)
# df.to_pickle(f"{PKL}/post_xtra_inspec_logbooks.pkl")

# %%
# Global view
fig, ax = plot_single_journey(df_usable, "Franklin (Ship) 1847-1850", save=True)

# %%
fig, ax = plot_single_journey(df_usable, "Franklin (Ship) 1847-1850", save = True, global_view=False, bounds=(20, 130, -70, 30) )

# %%
# Global view
fig, ax = plot_single_journey(df_usable, "Yeoman (Bark) 1843-1848", save=True)

# %%
#indian ocean bounds
fig, ax = plot_single_journey(df_usable, "Yeoman (Bark) 1843-1848", save = True, global_view=False, bounds=(20, 130, -70, 30) )

# %%
# Decadal view for Indian Ocean
plot_decadal_compact(df_usable, Figures, 1820, 1900, save = True, region="indian_ocean")
# Out:
# (<Figure size 1400x2400 with 9 Axes>,
#  array([<GeoAxes: title={'center': '1820s'}>,
#         <GeoAxes: title={'center': '1830s'}>,
#         <GeoAxes: title={'center': '1840s'}>,
#         <GeoAxes: title={'center': '1850s'}>,
#         <GeoAxes: title={'center': '1860s'}>,
#         <GeoAxes: title={'center': '1870s'}>,
#         <GeoAxes: title={'center': '1880s'}>,
#         <GeoAxes: title={'center': '1890s'}>], dtype=object))

# %%
# Decadal view for Indian Ocean
plot_global(df_usable, Figures, 1820, 1900, save=True, region="indian_ocean")
# Out:
# (<Figure size 1900x1200 with 2 Axes>,
#  <GeoAxes: title={'center': 'All Usable Entries • Indian Ocean'}>)

# %% [markdown]
# Plots of drought/flood prelim context for Josep Barriendos

# %%
# generate yearly plots for 1830, 1864, 1868, 1878 (droughts)

plot_time_range(df, Figures, start='1830-01-01', end='1831-01-01', color="tab:orange", save=True)

plot_time_range(df, Figures, start='1864-01-01', end='1865-01-01', color="tab:orange", save=True)

plot_time_range(df, Figures, start='1868-01-01', end='1869-01-01', color="tab:orange", save=True)

plot_time_range(df, Figures, start='1878-01-01', end='1879-01-01', color="tab:orange", save=True)
# Out:
# (<Figure size 1600x900 with 1 Axes>,
#  <GeoAxes: title={'center': 'All entries from 1878-01-01 to 1879-01-01 (n=1952)'}>)

# %%
# and more focused temporal ranges of (floods):
    #24-26 August 1842; 23-26 May 1853; 22-23 September 1874; 14-19 October 1879 and 21-28 May 1884

#not much usable data
#plot_time_range(df, Figures, start='1842-08-20', end='1842-08-30', color="tab:blue", save=False)

plot_time_range(df, Figures, start='1853-05-20', end='1853-05-28', color="tab:blue", save=True)

#not much usable data
#plot_time_range(df, Figures, start='1874-10-10', end='1874-10-23', color="tab:blue", save=False)

#no entries at all
#plot_time_range(df, Figures, start='1884-05-18', end='1884-05-30', color="tab:blue", save=False)
# Out:
# (<Figure size 1600x900 with 1 Axes>,
#  <GeoAxes: title={'center': 'All entries from 1853-05-20 to 1853-05-28 (n=52)'}>)
